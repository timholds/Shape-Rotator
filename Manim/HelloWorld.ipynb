# %%
from manim import *

config.media_width = "75%"
config.verbosity = "WARNING"

# %%
class HelloWorld(Scene):
    def construct(self):
        text = Text("Hello, World!")
        self.play(Write(text))
        self.wait()
        # clean up the text
        self.play(FadeOut(text))

        blue_circle = Circle(color=BLUE, fill_opacity=0.5)
        green_square = Square(color=GREEN, fill_opacity=0.8)
        self.play(Create(blue_circle))
        self.wait()
        
        self.play(Transform(blue_circle, green_square))
        self.wait()

# Render the scene in the notebook
# %manim -qm HelloWorld
# Out:
# <video src="media/jupyter/HelloWorld@2024-11-09@17-27-46.mp4" controls autoplay loop style="max-width: 75%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# Out:
# <video src="media/jupyter/L2NormInducedScene@2024-11-09@17-27-47.mp4" controls autoplay loop style="max-width: 75%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# Out:
# The manim module is not an IPython extension.
# <video src="media/jupyter/L2NormInducedScene@2024-11-09@17-27-48.mp4" controls autoplay loop style="max-width: 75%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# can i grab some real weights out of a trained focalnet modelon mnist
# show how a late interaction acually happens
